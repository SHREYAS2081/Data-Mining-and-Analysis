# %% [markdown]
# ## Hello Everyone..
# ### This is the Data Mining and Analysis project all about Food Order Analysis of a dataset from Zomato
#
# _____

# %%
# First of all we import all reqired librabries

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
import os 
import pandas as pd 
import seaborn as sns

# %% [markdown]
# -----
# #### Reading a csv file:

# %%
data=pd.read_csv(r"C:\Users\Yash Bhatnagar\Desktop\zomato.csv",encoding="ISO-8859-1")
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data1=pd.read_csv(r"C:\Users\Yash Bhatnagar\Desktop\cc.csv",encoding="ISO-8859-1")
data1.head() #for displaying first 5 data rows by default
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %% [markdown]
# -------
# #### To view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values:

# %%
data.describe()

#is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# -----
# #### To view all the columns in a dataset:

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# -----
# #### To view the datatype of the indivdual column:

# %%
data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# ____
# #### To check if there are any null values in the columns of our dataset:

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ____
# #### To count all the unique Cuisines in "Cuisines" column:

# %%
data["Cuisines"].nunique()
# Out:
# 1825

# %% [markdown]
# ____
# #### To show the shape of the dataset:

# %%
data.shape
# Out:
# (9551, 21)

# %% [markdown]
# ____
# #### To know the most frequently occuring unique object with its count:

# %%
data['Cuisines'].value_counts()
# Out:
# North Indian                                                           936
# North Indian, Chinese                                                  511
# Fast Food                                                              354
# Chinese                                                                354
# North Indian, Mughlai                                                  334
# Cafe                                                                   299
# Bakery                                                                 218
# North Indian, Mughlai, Chinese                                         197
# Bakery, Desserts                                                       170
# Street Food                                                            149
# Pizza, Fast Food                                                       131
# Chinese, Fast Food                                                     118
# ...

# %% [markdown]
# ___
# #### To filter the data in respect to the Country Code(Here INDIA):

# %%
c=data[data['Country Code']==1]   #"For the analysis of the dataset for the country INDIA"
c
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 624         3400025                                Jahanpanah             1
# 625         3400341                       Rangrezz Restaurant             1
# 626         3400005                   Time2Eat - Mama Chicken             1
# 627         3400021     Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                            Pinch Of Spice             1
# 629         3400325                                 MoMo Cafe             1
# 630         3400059                     Peshawri - ITC Mughal             1
# 631         3400060                     Taj Bano - ITC Mughal             1
# 632         3400348                                    G Thal             1
# 633         3400072              Dawat-e-Nawab - Radisson Blu             1
# 634         3400073               The Latitude - Radisson Blu             1
# ...

# %% [markdown]
# ____
# #### Filtering the dataset for INDIA on the basis of Aggregate Rating:

# %%
d=c[c['Aggregate rating'] >= 4].head(10)
d
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
# 629        3400325                              MoMo Cafe             1  Agra
# 630        3400059                  Peshawri - ITC Mughal             1  Agra
# 631        3400060                  Taj Bano - ITC Mughal             1  Agra
# 635        3400019                 Dasaprakash Restaurant             1  Agra
# 637        3400346                        Sheroes Hangout             1  Agra
# 641        3400105                              Pizza Hut             1  Agra
# 642        3400326       Tea'se Me - Rooftop Tea Boutique             1  Agra
# 643        3400392                             Thaaliwala             1  Agra
#
#                                                Address  \
# ...

# %% [markdown]
# ____
# #### To groupby the dataset on the basis of Cities in INDIA with its size:

# %%
h=c.groupby(['City']).size()
h
# Out:
# City
# Agra              20
# Ahmedabad         21
# Allahabad         20
# Amritsar          21
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Bhubaneshwar      21
# Chandigarh        18
# Chennai           20
# Coimbatore        20
# Dehradun          20
# Faridabad        251
# Ghaziabad         25
# Goa               20
# Gurgaon         1118
# Guwahati          21
# Hyderabad         18
# Indore            20
# Jaipur            20
# Kanpur            20
# Kochi             20
# Kolkata           20
# Lucknow           21
# Ludhiana          20
# Mangalore         20
# Mohali             1
# Mumbai            20
# Mysore            20
# Nagpur            20
# Nashik            20
# New Delhi       5473
# Noida           1080
# Panchkula          1
# Patna             20
# Puducherry        20
# Pune              20
# Ranchi            20
# Secunderabad       2
# Surat             20
# Vadodara          20
# Varanasi          20
# Vizag             20
# ...

# %% [markdown]
# ___
# #### Making a new dataframe for the total number of Votes per City:

# %%
f=c.groupby(['City']).sum()
s=pd.DataFrame(f['Votes'])
s
# Out:
#                Votes
# City
# Agra            2062
# Ahmedabad      12266
# Allahabad       1392
# Amritsar        3665
# Aurangabad      1296
# Bangalore      56115
# Bhopal          2877
# Bhubaneshwar    4243
# Chandigarh     10343
# Chennai        27695
# Coimbatore      4219
# Dehradun        2430
# Faridabad       6486
# Ghaziabad       2366
# Goa            15098
# Gurgaon       132160
# Guwahati        4964
# Hyderabad      24135
# Indore          4777
# Jaipur         11048
# Kanpur          1898
# Kochi           7199
# Kolkata        44593
# Lucknow         9130
# Ludhiana        2861
# Mangalore       4367
# Mohali            99
# Mumbai         29697
# Mysore          4258
# Nagpur          3456
# Nashik          2095
# New Delhi     628340
# Noida          73488
# Panchkula        843
# Patna           1520
# Puducherry      6848
# Pune           20732
# Ranchi          1807
# Secunderabad    1902
# Surat           3667
# Vadodara        3720
# Varanasi        1729
# ...

# %% [markdown]
# ____
# #### To make a new dataframe showing  mean Aggregate rating per City:

# %%
l=c.groupby(['City']).mean()
m=pd.DataFrame(l['Aggregate rating'])
m.reset_index()
# Out:
#             City  Aggregate rating
# 0           Agra          3.965000
# 1      Ahmedabad          4.161905
# 2      Allahabad          3.395000
# 3       Amritsar          3.685714
# 4     Aurangabad          3.375000
# 5      Bangalore          4.375000
# 6         Bhopal          3.950000
# 7   Bhubaneshwar          3.980952
# 8     Chandigarh          4.050000
# 9        Chennai          4.315000
# 10    Coimbatore          4.135000
# 11      Dehradun          4.050000
# 12     Faridabad          1.866932
# 13     Ghaziabad          2.852000
# 14           Goa          4.245000
# 15       Gurgaon          2.651431
# 16      Guwahati          4.190476
# 17     Hyderabad          4.344444
# 18        Indore          3.970000
# 19        Jaipur          4.130000
# 20        Kanpur          3.815000
# 21         Kochi          4.080000
# 22       Kolkata          4.255000
# 23       Lucknow          4.195238
# 24      Ludhiana          3.980000
# 25     Mangalore          3.745000
# ...

# %% [markdown]
# ____
# #### Plotting graph for the cities and there mean Aggregate rating:

# %%
plt.figure(figsize=(0,0))
m['City']=m.index
sns.factorplot(x='Aggregate rating',y='City',data=m, height=7, aspect=1)
plt.title("Plotting graph for the cities and there mean Aggregate rating")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5, 1, 'Plotting graph for the cities and there mean Aggregate rating')

# %% [markdown]
# ____
# #### HeatMap for the dataset for all Country Codes:

# %%
plt.figure(figsize=(10,8))
sd=sns.heatmap(data.corr(),annot=True)
plt.title("HeatMap for whole Dataset")
# Out:
# Text(0.5, 1, 'HeatMap for whole Dataset')

# %% [markdown]
# #### HeatMap for the dataset for INDIA:

# %%
plt.figure(figsize=(10,8))
sd=sns.heatmap(c.corr(),annot=True)
plt.title("HeatMap for India's Dataset")
# Out:
# Text(0.5, 1, "HeatMap for India's Dataset")

# %% [markdown]
# ___
# #### HeatMap for the dataset having restaurants in INDIA with rating>=4:

# %%
plt.figure(figsize=(10,8))
sd=sns.heatmap(d.corr(),annot=True)
plt.title("HeatMap for India's Dataset having rating >=4")
# Out:
# Text(0.5, 1, "HeatMap for India's Dataset having rating >=4")

# %% [markdown]
# ___
# #### BarPlot for the 'Price Range vs Aggregate Rating' for the restaurants in INDIA:

# %%
sns.barplot(x='Price range',y='Aggregate rating',data=c)
plt.title("Price Range vs Aggregate rating in India ")
# Out:
# Text(0.5, 1.0, 'Price Range vs Aggregate rating in India ')

# %% [markdown]
# ____
# #### BarPlot for the 'Aggregate Rating vs Votes' for food orders from restaurants in INDIA:

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Aggregate rating',y='Votes',data=c)
plt.title("Aggregate rating vs Votes in India")
# Out:
# Text(0.5, 1.0, 'Aggregate rating vs Votes in India')

# %% [markdown]
# ____
# #### BoxPlot for the votes per cities:

# %%
plt.figure(figsize=(10,6))
sns.set_style('whitegrid')
sns.boxplot(x='City',y='Votes',data=c.head(200),width=0.8)
plt.title("BoxPlot for the votes per cities")
# Out:
# Text(0.5, 1.0, 'BoxPlot for the votes per cities')

# %% [markdown]
# ____
# #### Histogram for the Aggregate rating :

# %%
sns.distplot(c['Aggregate rating'])
plt.title("Histogram for the Aggregate rating ")
# Out:
# Text(0.5, 1.0, 'Histogram for the Aggregate rating ')

# %% [markdown]
# ____
# #### BarPlot for Cuisines and their Votes:

# %%
plt.figure(figsize=(10,30))
sns.barplot(x='Votes',y='Cuisines',data=c.head(100))
plt.title("BarPlot for Cuisines and their Votes")
# Out:
# Text(0.5, 1.0, 'BarPlot for Cuisines and their Votes')

# %% [markdown]
# _____
# #### BarPlot for Cuisines and their Aggregate rating:

# %%
plt.figure(figsize=(10,30))
l=sns.barplot(x='Aggregate rating',y='Cuisines',data=c.head(100))
l
plt.title("BarPlot for Cuisines and their Aggregate rating")
# Out:
# Text(0.5, 1.0, 'BarPlot for Cuisines and their Aggregate rating')

# %% [markdown]
# ____
# #### BarPlot for Cuisines and their Price range:

# %%
plt.figure(figsize=(10,30))
sns.barplot(x='Price range',y='Cuisines',data=c.head(100))
plt.title("BarPlot for Cuisines and their Price range")
# Out:
# Text(0.5, 1.0, 'BarPlot for Cuisines and their Price range')

# %% [markdown]
# _____
# #### Scatter plot to show the overall rating text of cuisines:

# %%
plt.figure(figsize=(10,20))
ax = sns.scatterplot(x="Rating text", y="Cuisines",data=c.head(100))
plt.title("Scatter plot to show the overall rating text of cuisines")
# Out:
# Text(0.5, 1.0, 'Scatter plot to show the overall rating text of cuisines')

# %% [markdown]
# _____
# #### BarPlot to show the average cost for two per cuisines:

# %%
plt.figure(figsize=(10,20))
ax = sns.barplot(x="Average Cost for two", y="Cuisines",data=c.head(100))
plt.title("BarPlot to show the average cost for two per cuisine \n \n Black_Line_shows_Confidence_Interval")
# Out:
# Text(0.5, 1.0, 'BarPlot to show the average cost for two per cuisine \n \n Black_Line_shows_Confidence_Interval')

# %% [markdown]
# _____
# #### Scatter plot to show the average cost for two per cuisine:

# %%
plt.figure(figsize=(10,20))
ax = sns.scatterplot(x="Average Cost for two", y="Cuisines",data=c.head(100))
plt.title("Scatter plot to show the average cost for two per cuisine")
# Out:
# Text(0.5, 1.0, 'Scatter plot to show the average cost for two per cuisine')

# %% [markdown]
# ________
# ## Analysis or Conclusion according to the above Data Visualization:

# %% [markdown]
# -  New Delhi is the city form where highest number of votes for the food has been recorded.
# -  Secundarbad has the highest mean aggregate rating for the food among all the cities in India.
# -  Average cost for two and Price range of the food is the most strongly and positively related pair.
# -  In India higher the Price Range of the food higher is it's Aggregate rating.
# -  In India,4.8 food rating has the highest number of votes corresponding to it.
# -  In India,Chinese,Italian,North Indian,Mexican,Mediterranean,Thai combined ordered food cuisine set has the highest number of    votes.
# -  In India,Cafe,North Indian,Chinese combined food cuisine set has the highest aggregate food rating.
# -  In India,'North Indian,Chinese,Continental','Contitnental,Italian' and 'North Indian,European' food cuisine set has the        highest price range.
# -  In India,'Cafe,North Indian,Chinese','Icecream,Desserts,Continental' and 'North Indian,Continental,Beverages,Italian            Burger,Healthy Food,Meditirranean' food cuisine sets have the Excellent Food Rating text.
# -  In India,'North Indian,Mughlai','Mughlai' and 'North Indian,European' has the highest Average cost for two.

# %% [markdown]
# _______
#
# ## Thank You..
#
# ______
